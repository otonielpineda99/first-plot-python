# %% [markdown]
#     PLOTS Y VISUALIZACION DE DATA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\arman\Documents\data-science\python-ml-course-master\datasets\customer-churn-model\Customer Churn Model.txt")

# %%
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
# %matplotlib inline

# %%
#savefig("C:\Users\arman\Documents\data-science.jpeg")

# %% [markdown]
# SCATTER PLOT

# %%
data.plot(kind="scatter", x="Day Mins", y="Day Charge")
# Out:
# <Axes: xlabel='Day Mins', ylabel='Day Charge'>

# %%
data.plot(kind="scatter", x="Night Mins", y="Night Charge")
# Out:
# <Axes: xlabel='Night Mins', ylabel='Night Charge'>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
data.plot(kind="scatter", x="Day Mins", y="Day Charge", ax=axs[0][0])
data.plot(kind="scatter", x="Night Mins", y="Night Charge", ax=axs[0][1])

data.plot(kind="scatter", x="Day Calls", y="Day Charge", ax=axs[1][0])
data.plot(kind="scatter", x="Night Calls", y="Night Charge", ax=axs[1][1])
# Out:
# <Axes: xlabel='Night Calls', ylabel='Night Charge'>

# %% [markdown]
# HISTOGRAMA DE FRECUENCIA

# %%
k = int(np.ceil(1+np.log2(3333))) # En el log2 usamos la muestra que es de 3333
plt.hist(data["Day Calls"], bins = k)
plt.xlabel("Numero de llamadas al día")
plt.ylabel("Frecuencia")
plt.title("Histograma de Número de llamadas al día")
# Out:
# Text(0.5, 1.0, 'Histograma de Número de llamadas al día')

# %% [markdown]
# BOXPLOT, Diagrama de caja y bigotes

# %%
plt.boxplot(data["Day Calls"]) #Dentro de la caja se ven los valores entre los cuantiles del 25% y el 100%
plt.ylabel("Numero de llamadas diarias")
plt.title("BOXPLOT Llamadas diarias")
# Out:
# Text(0.5, 1.0, 'BOXPLOT Llamadas diarias')

# %%
data["Day Calls"].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Day Calls, dtype: float64

# %%
IQR = data["Day Calls"].quantile(0.75) - data["Day Calls"].quantile(0.25) #Este es el dato interquantilico
IQR
# Out:
# 27.0

# %%
data["Day Calls"].quantile(0.25) - 1.5*IQR
# Out:
# 46.5

# %%
data["Day Calls"].quantile(0.75) + 1.5*IQR
# Out:
# 154.5
